# %%
def isPalindrome(string):
    print("-"*25)
    print("입력된 문자열: ", string)

    test = string[::-1]
    print("뒤집힌 문자열: ", test, "\n", "-"*25)
    if string == test:
        print("회문임")
    else:
        print("회문아님")

string = input()
isPalindrome(string)
# Out:
# 망아지
# -------------------------
# 입력된 문자열:  망아지
# 뒤집힌 문자열:  지아망
#  -------------------------
# 회문아님
